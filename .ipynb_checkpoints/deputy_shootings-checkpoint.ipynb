# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import tensorflow as tf
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras import backend as k
from keras.layers import Dense,Activation,Dropout
from keras.layers.core import Flatten
from pylab import rcParams
import matplotlib.pyplot as plt
import gmaps
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
shootings_data = pd.read_csv('deputy_shootings.csv',header=0)

# %%
inc_date = shootings_data["INCIDENT DATE"]
inc_date.head(20)
# Out:
# 0      2/13/2017 14:45
# 1      2/17/2017 11:30
# 2       3/7/2017 23:05
# 3      3/11/2017 11:12
# 4       6/27/2013 7:30
# 5      2/24/2016 17:14
# 6      7/31/2012 11:15
# 7       2/5/2011 21:56
# 8     12/14/2011 11:23
# 9      8/23/2014 21:10
# 10     2/11/2016 18:42
# 11     9/15/2014 13:00
# 12      2/3/2012 19:10
# 13       8/6/2014 6:05
# 14      7/3/2015 23:30
# 15     4/13/2014 16:05
# 16     6/15/2010 19:30
# 17      1/31/2015 9:35
# 18      5/24/2014 1:50
# 19      9/18/2012 5:45
# Name: INCIDENT DATE, dtype: object

# %%
#convert date reported to date object
try:
    date_occ = [dt.datetime.strptime(d, "%m/%d/%Y %H:%M" ) for d in inc_date]
except:
    print("Error Date Format")
shootings_data["INCIDENT DATE"] = np.array(date_occ)

day = [data.isoweekday() for data in shootings_data["INCIDENT DATE"]]
mon = [data.month for data in shootings_data["INCIDENT DATE"]]
year = [data.year for data in shootings_data["INCIDENT DATE"]]
time = [data.hour for data in shootings_data["INCIDENT DATE"]]

shootings_data["DAY"] = np.array(day)
shootings_data["MONTH"] = np.array(mon)
shootings_data["YEAR"] = np.array(year)
shootings_data["HOUR"] = np.array(time)

# %%
shootings_data.head(5)
# Out:
#    INCIDENT NUMBER             INCIDENT TYPE       INCIDENT DATE  \
# 0          1001037     HIT SHOOTING INCIDENT 2017-02-13 14:45:00
# 1          1001038  ANIMAL SHOOTING INCIDENT 2017-02-17 11:30:00
# 2          1001076     HIT SHOOTING INCIDENT 2017-03-07 23:05:00
# 3          1001096     WARNING SHOT INCIDENT 2017-03-11 11:12:00
# 4          1000131  ANIMAL SHOOTING INCIDENT 2013-06-27 07:30:00
#
#           INCIDENT LOCATION         CITY STATE    ZIP  REPORTING DISTRICT  \
# 0      7300 VAN NUYS BLVD.,     VAN NUYS    CA  91405              6884.0
# 1    800 E. LANGHORN STREET    LANCASTER    CA  93535              1100.0
# 2  5000 WEST SLAUSON AVENUE  LOS ANGELES    CA  90056              2767.0
# 3       13100 E. AVENUE R-6   LITTLEROCK    CA  93543              2663.0
# 4    1200 E. GLENCOE STREET      COMPTON    CA  90221              2844.0
#
#   HANDLING UNIT ID                                       GEO_LOCATION  \
# 0              TBN  7300 VAN NUYS BLVD.,\nVAN NUYS, CA 91405\n(34....
# 1              LCS  800 E. LANGHORN STREET\nLANCASTER, CA 93535\n(...
# 2              MAR  5000 WEST SLAUSON AVENUE\nLOS ANGELES, CA 9005...
# 3              PLM  13100 E. AVENUE R-6\nLITTLEROCK, CA 93543\n(34...
# 4              COP  1200 E. GLENCOE STREET\nCOMPTON, CA 90221\n(33...
#
#      HANDLING UNIT NAME  APPROX_LATITUDE  APPROX_LONGITUDE  Zip Codes  \
# 0  TRANSIT BUREAU NORTH        34.204816       -118.448737    19733.0
# 1         LANCASTER STN        34.698846       -118.115660    26966.0
# 2    MARINA DEL REY STN        33.987686       -118.365680    24351.0
# 3          PALMDALE STN        34.567335       -117.925342    27318.0
# 4           COPS BUREAU        33.882160       -118.209067    24350.0
#
#    2011 Supervisorial District Boundaries (Official)  DAY  MONTH  YEAR  HOUR
# 0                                                3.0    1      2  2017    14
# 1                                                5.0    5      2  2017    11
# 2                                                2.0    2      3  2017    23
# 3                                                5.0    6      3  2017    11
# 4                                                2.0    4      6  2013     7

# %%
week_day = { 
    1:"Monday",
    2:"Tuesday",
    3:"Wednesday",
    4:"Thursday",
    5:"Friday",
    6:"Saturday",
    7:"Sunday"
}
shootings_data['DAY'] = shootings_data['DAY'].map(week_day)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.barplot(y=shootings_data["DAY"].value_counts().index[0:20],x=shootings_data["DAY"].value_counts().head(20), ax=ax)
# Axes
ax.set_title("Shootings By Day")
ax.set_xlabel("Shootings Count")
ax.set_ylabel("DAYS")
sns.despine()
#fig.savefig('shootings_day.png')

# %%
month_year = { 
    1:"January",
    2:"February",
    3:"March",
    4:"April",
    5:"May",
    6:"June",
    7:"July",
    8:"August",
    9:"September",
    10:"October",
    11:"November",
    12:"December"
}
shootings_data['MONTH'] = shootings_data['MONTH'].map(month_year)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.barplot(y=shootings_data["MONTH"].value_counts().index[0:20],x=shootings_data["MONTH"].value_counts().head(20), ax=ax)
# Axes
ax.set_title("Shootings By Month")
ax.set_xlabel("Shootings Count")
ax.set_ylabel("MONTH")
sns.despine()

# %%
shootings_data["YEAR"].value_counts()
# Out:
# 2012    103
# 2010    101
# 2013     94
# 2014     79
# 2011     78
# 2015     74
# 2017     58
# 2016     58
# 2018     18
# Name: YEAR, dtype: int64

# %%
shootings_data["HOUR"].value_counts()
# Out:
# 21    61
# 17    36
# 16    35
# 12    35
# 8     34
# 11    33
# 22    33
# 23    32
# 20    31
# 18    29
# 15    28
# 19    25
# 10    24
# 9     24
# 4     24
# 3     24
# 14    23
# 5     23
# 1     23
# 7     20
# 0     19
# 13    16
# 6     16
# 2     15
# Name: HOUR, dtype: int64

# %%
fig, ax = plt.subplots()
# Plotting crime through the hours
ax = plt.plot(shootings_data["HOUR"].value_counts().sort_index().index, shootings_data["HOUR"].value_counts().sort_index())
# Axes
fig.set_size_inches(11.7, 8.27)
plt.title("Shootings by the Hour")
plt.xticks(range(24))
plt.xlim(0,23)
plt.xlabel("Time (24 hour format)")
plt.ylabel("Total Shootings Occurring")
sns.despine()

# %%
shootings_data['HOUR'].describe()[1:]
# Out:
# mean    12.918552
# std      6.867059
# min      0.000000
# 25%      8.000000
# 50%     14.000000
# 75%     19.000000
# max     23.000000
# Name: HOUR, dtype: float64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
# Plotting victim's age distribution
sns.distplot(shootings_data['HOUR'], bins=24, ax=ax)
# Axes
ax.set_title("SHOOTINGS BY THE HOUR")
ax.set_xlabel("HOUR")
ax.set_ylabel("Probability of Being Shot")
sns.despine()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
# Plotting victim's age distribution
sns.distplot(shootings_data['YEAR'], bins=24, ax=ax)
# Axes
ax.set_title("SHOOTINGS BY THE MONTH")
ax.set_xlabel("YEAR")
ax.set_ylabel("Probability of Being Shot")
sns.despine()

# %%
list(shootings_data)
# Out:
# ['INCIDENT NUMBER',
#  'INCIDENT TYPE',
#  'INCIDENT DATE',
#  'INCIDENT LOCATION',
#  'CITY',
#  'STATE',
#  'ZIP',
#  'REPORTING DISTRICT',
#  'HANDLING UNIT ID',
#  'GEO_LOCATION',
#  'HANDLING UNIT NAME',
#  'APPROX_LATITUDE',
#  'APPROX_LONGITUDE',
#  'Zip Codes',
#  '2011 Supervisorial District Boundaries (Official)',
#  'DAY',
#  'MONTH',
#  'YEAR',
#  'HOUR']

# %%
shootings_data['CITY'].value_counts().head(20)
# Out:
# LOS ANGELES         136
# COMPTON              80
# LANCASTER            45
# PALMDALE             25
# EAST LOS ANGELES     16
# PICO RIVERA          14
# CARSON               14
# PARAMOUNT            13
# LYNWOOD              13
# NORWALK              11
# WHITTIER             11
# BELLFLOWER           11
# LA PUENTE            10
# LAKEWOOD              9
# CITY OF INDUSTRY      8
# CASTAIC               7
# WEST HOLLYWOOD        7
# MAYWOOD               7
# LITTLEROCK            7
# LA MIRADA             6
# Name: CITY, dtype: int64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.barplot(y=shootings_data["CITY"].value_counts().index[0:20],x=shootings_data["CITY"].value_counts().head(20), ax=ax)
# Axes
ax.set_title("Shootings By Cities")
ax.set_xlabel("Shootings Count")
ax.set_ylabel("Cities")
sns.despine()
fig.savefig('Shootings_cities.png')

# %%
shootings_data['HANDLING UNIT NAME'].value_counts().head(20)
# Out:
# COMPTON STN                      66
# CENTURY STN                      64
# EAST LA STN                      42
# LAKEWOOD STN                     42
# LANCASTER STN                    42
# OPERATION SAFE STREETS BUREAU    37
# SOUTH LOS ANGELES STATION        33
# PALMDALE STN                     32
# INDUSTRY STN                     25
# PICO RIVERA STN                  18
# COPS BUREAU                      17
# SPECIAL ENFORCEMENT BUR          17
# TEMPLE CITY STN                  16
# CARSON STN                       15
# NARCOTICS BUREAU                 15
# SANTA CLARITA VALLEY STN         14
# NORWALK REGIONAL STN             14
# TRANSIT SERVICES BUREAU          11
# WEST HOLLYWOOD STN               10
# WALNUT/SAN DIMAS STN              9
# Name: HANDLING UNIT NAME, dtype: int64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.barplot(y=shootings_data["HANDLING UNIT NAME"].value_counts().index[0:20],x=shootings_data["HANDLING UNIT NAME"].value_counts().head(20), ax=ax)
# Axes
ax.set_title("HANDLING UNITS")
ax.set_xlabel("Shootings Count")
ax.set_ylabel("HANDLING NAME")
sns.despine()
fig.savefig('handling_units.png')

# %%
gmaps.configure(api_key="AIzaSyAqwJxMN_qjXi2FnyvTRROKtt6wfqCzFfo")
locations = shootings_data[["APPROX_LATITUDE","APPROX_LONGITUDE"]]
#fig = gmaps.figure()
#fig.add_layer(gmaps.heatmap_layer(locations))
#gmaps.heatmap(locations)

shootings_loc = gmaps.symbol_layer(locations,fill_color="red",stroke_color="red",scale=1)
fig = gmaps.figure(layout={
        'width': '950px',
        'height': '600px',
        'padding': '3px',
        'border': '1px solid black'
})
fig.add_layer(shootings_loc)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='3px', width='950px'))

# %% [markdown]
# # HeatMap

# %%
locations = shootings_data[["APPROX_LATITUDE","APPROX_LONGITUDE"]]
fig = gmaps.figure(layout={
        'width': '950px',
        'height': '600px',
        'padding': '3px',
        'border': '1px solid black'
})
heatmap = gmaps.heatmap_layer(locations)
#heatmap.max_intensity = 2
#heatmap.point_radius = 3
#heatmap.gradient = ['white', 'gray']
fig.add_layer(heatmap)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='3px', width='950px'))

# %%
from astral import Astral
import datetime
#    0 = New Moon
#    7 = First Quarter
#    14 = Full Moon
#    21 = Last Quarter

# %% [markdown]
# The moon phase method returns an number describing the phase, where the value is between 0 and 27 (27.99 if you pass float as the return type). The following lists the mapping of various vales to the description of the phase of the moon.
#
#     0 = New Moon
#     7 = First Quarter
#     14 = Full Moon
#     21 = Last Quarter
#
# If for example the number returned was 27(.99) then the moon would be almost at the New Moon phase, and if it was 24 it would be half way between the Last Quarter and a New Moon.

# %%
a = Astral()
moon_phase = a.moon_phase(date=datetime.date(2010,1,1))
print(moon_phase)
# Out:
# 14

# %%
def moon_trans(val):
    if(val>=0 and val<=3.5):
        return "New_Moon"
    elif(val>=3.6 and val<=7):
        return "First_Quarter"
    elif(val>7 and val<=10.5):
        return ""
    elif(val>10.6 and val<=14):
        return ""

# %%
m_phase = [a.moon_phase(d.date()) for d in date_occ]
shootings_data["MOON_PHASE"] = np.array(m_phase)
shootings_data
# Out:
#      INCIDENT NUMBER                     INCIDENT TYPE       INCIDENT DATE  \
# 0            1001037             HIT SHOOTING INCIDENT 2017-02-13 14:45:00
# 1            1001038          ANIMAL SHOOTING INCIDENT 2017-02-17 11:30:00
# 2            1001076             HIT SHOOTING INCIDENT 2017-03-07 23:05:00
# 3            1001096             WARNING SHOT INCIDENT 2017-03-11 11:12:00
# 4            1000131          ANIMAL SHOOTING INCIDENT 2013-06-27 07:30:00
# 5            1000687             HIT SHOOTING INCIDENT 2016-02-24 17:14:00
# 6            1000095          ANIMAL SHOOTING INCIDENT 2012-07-31 11:15:00
# 7            1000338             HIT SHOOTING INCIDENT 2011-02-05 21:56:00
# 8            1000072          ANIMAL SHOOTING INCIDENT 2011-12-14 11:23:00
# 9            1000251  UNINTENTIONAL DISCHARGE INCIDENT 2014-08-23 21:10:00
# 10           1000683             HIT SHOOTING INCIDENT 2016-02-11 18:42:00
# 11           1000149          ANIMAL SHOOTING INCIDENT 2014-09-15 13:00:00
# 12           1000380         NON-HIT SHOOTING INCIDENT 2012-02-03 19:10:00
# 13           1000177          ANIMAL SHOOTING INCIDENT 2014-08-06 06:05:00
# 14           1000530             HIT SHOOTING INCIDENT 2015-07-03 23:30:00
# 15           1000482             HIT SHOOTING INCIDENT 2014-04-13 16:05:00
# 16           1000029          ANIMAL SHOOTING INCIDENT 2010-06-15 19:30:00
# 17           1000157          ANIMAL SHOOTING INCIDENT 2015-01-31 09:35:00
# 18           1000487             HIT SHOOTING INCIDENT 2014-05-24 01:50:00
# 19           1000214  UNINTENTIONAL DISCHARGE INCIDENT 2012-09-18 05:45:00
# 646                 11200 BROADMEAD STREET    SOUTH EL MONTE    CA  91733
# 647          ROSCOE BLVD AT WHITE OAK AVE.            RESEDA    CA  91335
# 648                     2100 SHAUER STREET       WILLOWBROOK    CA  90222
# 649                     8700 WEST AVENUE H         LANCASTER    CA  93536
# 650           45900 247TH EAST STREET EAST         LANCASTER    CA  93535
# 651                   6000 CANYONSIDE ROAD      LA CRESCENTA    CA  91214
# 652             2100 S. ATLANTIC BOULEVARD          COMMERCE    CA  90040
# 653                     11900 168TH STREET           ARTESIA    CA  90701
# 654                   3400 WEST 11TH PLACE         INGLEWOOD    CA  90303
# 655                      27000 AGOURA ROAD         CALABASAS    CA  91301
# 656                  5500 RIMPAU BOULEVARD       LOS ANGELES    CA  90043
# 657               500 NORTH ALAMEDA AVENUE             AZUSA    CA  91702
# 658                   2300 LIGHTCAP STREET         LANCASTER    CA  93535
# 659              21900 SOUTH MARTIN STREET            CARSON    CA  90745
# 660                  21300 BOTTLETREE LANE     SANTA CLARITA    CA  91321
# 661                       1100 WEST AVENUE         LANCASTER    CA  93534
# 662               17300 EAST TEMPLE AVENUE           VALINDA    CA  91744
#
#      REPORTING DISTRICT HANDLING UNIT ID  \
# 0                6884.0              TBN
# 1                1100.0              LCS
# 2                2767.0              MAR
# 3                2663.0              PLM
# 4                2844.0              COP
# 5                2310.0              CER
# 6                3661.0            NARCO
# 7                2603.0              PLM
# 8                 388.0              SLA
# 9                1431.0              IDT
# 10               1137.0              LCS
# 11               2223.0              LHS
# 12               2822.0              COM
# 13               1351.0              LKD
# 14               1192.0              OSS
# 15               2112.0              CEN
# 16               1137.0              LCS
# 17               2608.0              PLM
# 18                987.0              WHD
# 19               2199.0              SEB
# 20               1182.0              LCS
# 21                774.0              ALD
# 22               2826.0              COM
# 23               2811.0              COM
# 24               2842.0              OSS
# 25               1349.0              LKD
# 26               2199.0              CEN
# 27               2822.0              COM
# 28                972.0              WHD
# 29               2814.0              COM
# ..                  ...              ...
# 633              2117.0              CEN
# 634               282.0              ELA
# 635              1620.0              CSN
# 636              2916.0              WAL
# 637              3199.0              HOM
# 638              2131.0              CEN
# 639              2610.0              PLM
# 640              1871.0              AVA
# 641                 NaN               TB
# 642              2610.0              PLM
# 643              1420.0              IND
# 644              5640.0              NCF
# 645                 NaN              SLA
# 646              3605.0              NAR
# 647              8548.0              CSB
# 648              2136.0              SEB
# 649              1187.0              LCS
# 650              1194.0              LCS
# 651                 NaN              CRV
# 652               243.0              ELA
# 653              1348.0              NWK
# 654                 NaN              MCJ
# 655              2242.0              MLH
# 656              2768.0              MAR
# 657                 NaN               SO
# 658              1137.0              LCS
# 659              1628.0              CSN
# 660               627.0              SCV
# 661              1121.0              OSS
# 662              1442.0              IND
#
#                                           GEO_LOCATION  \
# 0    7300 VAN NUYS BLVD.,\nVAN NUYS, CA 91405\n(34....
# 1    800 E. LANGHORN STREET\nLANCASTER, CA 93535\n(...
# 2    5000 WEST SLAUSON AVENUE\nLOS ANGELES, CA 9005...
# 3    13100 E. AVENUE R-6\nLITTLEROCK, CA 93543\n(34...
# 644    19338.0                                                5.0    Tuesday
# 645    23678.0                                                2.0  Wednesday
# 646     9314.0                                                1.0   Thursday
# 647    18514.0                                                3.0    Tuesday
# 648    24677.0                                                2.0   Thursday
# 649    26967.0                                                5.0  Wednesday
# 650    26966.0                                                5.0     Monday
# 651     4275.0                                                5.0   Saturday
# 652    23671.0                                                1.0  Wednesday
# 653    26323.0                                                4.0     Monday
# 654    25425.0                                                2.0   Saturday
# 655     4277.0                                                3.0     Friday
# 656    23674.0                                                2.0     Monday
# 657     8894.0                                                1.0  Wednesday
# 658    26966.0                                                5.0  Wednesday
# 659     3354.0                                                2.0     Monday
# 660     4290.0                                                5.0    Tuesday
# 661    26965.0                                                5.0    Tuesday
# 662     9324.0                                                1.0     Friday
#
#          MONTH  YEAR  HOUR  MOON_PHASE
# 0     February  2017    14          16
# 1     February  2017    11          19
# 2        March  2017    23           9
# 3        March  2017    11          12
# 4         June  2013     7          18
# 5     February  2016    17          15
# 6         July  2012    11          12
# 7     February  2011    21           2
# 8     December  2011    11          17
# 9       August  2014    21          26
# 10    February  2016    18           2
# 11   September  2014    13          20
# 12    February  2012    19           9
# 13      August  2014     6           9
# 14        July  2015    23          15
# 15       April  2014    16          12
# 16        June  2010    19           3
# 17     January  2015     9          11
# 18         May  2014     1          23
# 19   September  2012     5           2
# 20        July  2012    22           0
# 21    February  2015     0          21
# 22        July  2013    12          19
# 23      August  2012    23          13
# 24         May  2015     6           1
# 25    December  2017    21          21
# 26    December  2017     2          17
# 27     January  2018     8          14
# 28         May  2011    20          19
# 29    December  2014    17           9
# ..         ...   ...   ...         ...
# 633    October  2010     0           2
# 634  September  2012    22          12
# 635     August  2017    23          11
# 636       July  2017     7          16
# 637     August  2017    12          14
# 638     August  2017    19          22
# 639       July  2017    13          10
# 640     August  2017    21           8
# 641     August  2017     7          27
# 642     August  2017     7           4
# 643  September  2017    17          19
# 644  September  2017    12           5
# 645    October  2017     1          19
# 646    October  2017     5          13
# 647    October  2017     6          10
# 648   November  2017    16          12
# 649       July  2016     4          14
# 650       July  2016     0          19
# 651   November  2017     9          21
# 652    October  2015    23           7
# 653   November  2017    16           1
# 654   November  2017    17           6
# 655   December  2017    21          11
# 656   November  2017     5          16
# 657  September  2017    17          21
# 658   December  2017    16          17
# 659   November  2017    21          16
# 660   November  2017    22           8
# 661    January  2016    17           2
# 662  September  2017     3          16
#
# [663 rows x 20 columns]

# %%
shootings_data["MOON_PHASE"].describe()
# Out:
# count    663.000000
# mean      13.042232
# std        7.944180
# min        0.000000
# 25%        6.000000
# 50%       13.000000
# 75%       20.000000
# max       27.000000
# Name: MOON_PHASE, dtype: float64

# %%
fig, ax = plt.subplots()
# Plotting crime through the hours
ax = plt.plot(shootings_data["MOON_PHASE"].value_counts().sort_index().index, shootings_data["MOON_PHASE"].value_counts().sort_index())
# Axes
fig.set_size_inches(11.7, 8.27)
plt.title("Shootings by the Hour")
plt.xticks(range(27))
plt.xlim(0,27)
plt.xlabel("Time (24 hour format)")
plt.ylabel("Total Shootings Occurring")
# Out:
# Text(0,0.5,'Total Shootings Occurring')
